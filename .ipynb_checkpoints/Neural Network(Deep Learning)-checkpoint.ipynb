# %% [markdown]
# ### 신경망(Neural Network) (딥러닝, Deep Learning)

# %% [markdown]
# #### 신경망 모델

# %%
from IPython.display import display
import mglearn
display(mglearn.plots.plot_logistic_regression_graph())

# %%
display(mglearn.plots.plot_single_hidden_layer_graph())

# %% [markdown]
# [은닉층이 하나인 다층 퍼셉트론]

# %%
import numpy as np
import matplotlib.pyplot as plt
line = np.linspace(-3, 3, 100)
plt.plot(line, np.tanh(line), label="tanh")
plt.plot(line, np.maximum(line, 0), linestyle='--', label="relu")
plt.legend(loc="best")
plt.xlabel("x")
plt.ylabel("relu(x), tanh(x)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-43414249b3f9> in <module>
#       1 import numpy as np
#       2 line = np.linspace(-3, 3, 100)
# ----> 3 plt.plot(line, np.tanh(line), label="tanh")
#       4 plt.plot(line, np.maximum(line, 0), linestyle='--', label="relu")
#       5 plt.legend(loc="best")
#
# NameError: name 'plt' is not defined
