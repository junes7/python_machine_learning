# %% [markdown]
# ### K-최근접 이웃 회귀

# %%
import mglearn
mglearn.plots.plot_knn_regression(n_neighbors=1)

# %% [markdown]
# * 여러 개의 최근접 이웃을 사용할 땐 이웃 간의 평균이 예측이 됩니다.

# %%
mglearn.plots.plot_knn_regression(n_neighbors=3)

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
import mglearn
X, y = mglearn.datasets.make_wave(n_samples=40)

# wave 데이터셋을 훈련 세트와 테스트 세트로 나눕니다.
X_train, y_train, X_test, y_test = train_test_split(X, y, random_state=0)
# 이웃의 수를 3으로 하여 모델의 객체를 만듭니다.
reg = KNeighborsRegressor(n_neighbors=3)
# 훈련 데이터와 타깃을 사용하여 모델을 학습시킵니다.
reg.fit(X_train, y_train)
# Out:
# --------------------------------------------------------------------
# ValueError                         Traceback (most recent call last)
# <ipython-input-4-a8e9e8795a5f> in <module>
#       9 reg = KNeighborsRegressor(n_neighbors=3)
#      10 # 훈련 데이터와 타깃을 사용하여 모델을 학습시킵니다.
# ---> 11 reg.fit(X_train, y_train)
#
# c:\users\wnstj\appdata\local\programs\python\python37\lib\site-packages\sklearn\neighbors\_regression.py in fit(self, X, y)
#     188             The fitted k-nearest neighbors regressor.
#     189         """
# --> 190         return self._fit(X, y)
#     191
#     192     def predict(self, X):
#
# c:\users\wnstj\appdata\local\programs\python\python37\lib\site-packages\sklearn\neighbors\_base.py in _fit(self, X, y)
#     362             if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
#     363                 X, y = self._validate_data(X, y, accept_sparse="csr",
# --> 364                                            multi_output=True)
#     365
#     366             if is_classifier(self):
#
# c:\users\wnstj\appdata\local\programs\python\python37\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# c:\users\wnstj\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\wnstj\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     829         y = y.astype(np.float64)
#     830
# --> 831     check_consistent_length(X, y)
#     832
#     833     return X, y
#
# c:\users\wnstj\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     261     if len(uniques) > 1:
#     262         raise ValueError("Found input variables with inconsistent numbers of"
# --> 263                          " samples: %r" % [int(l) for l in lengths])
#     264
#     265
#
# ValueError: Found input variables with inconsistent numbers of samples: [30, 10]

# %%
print("테스트 세트 예측:\n", reg.predict(X_test))
# Out:
# --------------------------------------------------------------------
# ValueError                         Traceback (most recent call last)
# <ipython-input-5-bf574190cb5a> in <module>
# ----> 1 print("테스트 세트 예측:\n", reg.predict(X_test))
#
# c:\users\wnstj\appdata\local\programs\python\python37\lib\site-packages\sklearn\neighbors\_regression.py in predict(self, X)
#     204             Target values.
#     205         """
# --> 206         X = check_array(X, accept_sparse='csr')
#     207
#     208         neigh_dist, neigh_ind = self.kneighbors(X)
#
# c:\users\wnstj\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\wnstj\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     639                     "Reshape your data either using array.reshape(-1, 1) if "
#     640                     "your data has a single feature or array.reshape(1, -1) "
# --> 641                     "if it contains a single sample.".format(array))
#     642
#     643         # make sure we actually converted to numeric:
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[ 0.69798591  1.87664889 -1.41502356  0.77932073  0.09398858  0.03527881
#   0.86893293  0.08448544  0.0945257   1.00032374 -1.51369739 -2.47196233
#  -0.52734666 -1.67303415  1.53708251  1.49417157 -0.47411033  0.33122576
#  -1.13455014  0.75418806 -2.08581717 -0.98618122 -1.52730805  0.09756349
#  -1.12469096 -0.3409073   0.22956153  0.25438895  0.03497884 -0.44822073].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
